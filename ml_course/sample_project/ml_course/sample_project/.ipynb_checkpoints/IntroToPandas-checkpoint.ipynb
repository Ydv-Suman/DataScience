# %%
import pandas as pd

# %%
# 2 main datatypes
Series = pd.Series(["Nissan","Toyota","Prosche"])

# %%
Series
# Out:
# 0     Nissan
# 1     Toyota
# 2    Prosche
# dtype: object

# %%
# Series = 1-dimensional

# %%
Colors = pd.Series(["red","black","blue","yellow"])
Colors
# Out:
# 0       red
# 1     black
# 2      blue
# 3    yellow
# dtype: object

# %%
# dataframe = 2-dimensional

# %%
car_detail = pd.DataFrame({"car make": Series, "color": Colors})
car_detail
# Out:
#   car make   color
# 0   Nissan     red
# 1   Toyota   black
# 2  Prosche    blue
# 3      NaN  yellow

# %%
# NaN because no car is assigned for index 3

# %% [markdown]
# ## Reading csv file

# %%
car_sales = pd.read_csv("car-sales.csv")
car_sales.head
# Out:
# <bound method NDFrame.head of      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00>

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# 1. Row referred as axis 0
# 2. column referred as axis 1
# 3. index number start at 0 by default

# %%
# Exporting dataframe
car_sales.to_csv("exported-car_sales")

# %%
export_car_sales = pd.read_csv("exported-car_sales.csv", index_col=0)
export_car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# ## if index_col = 0 not provided after csv filename it will export as index column(prevent from interpreting first column as index). It will shows Unnamed

# %% [markdown]
# ## Describe Data

# %%
# Attribute 
car_sales.dtypes

# function
# car_sales.to_csv()
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_column = car_sales.columns
car_column
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
car_sales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
## price is not included because price is object not int

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 532.0+ bytes

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.mean(numeric_only=True)
# Out:
# Odometer (KM)    78601.4
# Doors                4.0
# dtype: float64

# %%
car_prices = pd.Series([1000,2000,3000])
car_prices.mean()
# Out:
# np.float64(2000.0)

# %%
car_sales.sum()
# Out:
# Make             ToyotaHondaToyotaBMWNissanToyotaHondaHondaToyo...
# Colour               WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite
# Odometer (KM)                                               786014
# Doors                                                           40
# Price            $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...
# dtype: object

# %%
car_sales['Doors'].sum()
# Out:
# np.int64(40)

# %%
car_sales['Odometer (KM)'].sum()
# Out:
# np.int64(786014)

# %%
car_sales['Doors'].mean()
# Out:
# np.float64(4.0)

# %%
len(car_sales)
# Out:
# 10

# %% [markdown]
# ## Viewing and selecting Data

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
## only display 5 by default from top
## providing number will display that much of data from top

# %%
car_sales.head(8)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00

# %%
car_sales.tail()
car_sales.tail(8)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
## only display 5 by default from bottom
## providing number will display that much of data from bottom

# %% [markdown]
# ## .loc & .iloc

# %%
animal = pd.Series(['cat', 'dog', 'panda', 'python'], index=[0, 2, 3, 0])
animal
# Out:
# 0       cat
# 2       dog
# 3     panda
# 0    python
# dtype: object

# %%
## index for the data can be set by passing index value

# %%
## loc
## loc refers to index
## iloc refers to position

# %%
animal.loc[0]
# Out:
# 0       cat
# 0    python
# dtype: object

# %%
animal.loc[2]
# Out:
# 'dog'

# %%
car_sales.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %% [markdown]
# ## iloc

# %%
animal.iloc[2]
# Out:
# 'panda'

# %%
car_sales.iloc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
animal.iloc[:2]
# Out:
# 0    cat
# 2    dog
# dtype: object

# %%
car_sales.loc[:3]
## same as 
car_sales.head(3)
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 1   Honda    Red          87899      4  $5,000.00
# 2  Toyota   Blue          32549      3  $7,000.00

# %%
car_sales["Make"].loc[:4]
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# Name: Make, dtype: object

# %%
car_sales["Make"]
## this will work same as its just the difference of syntax
car_sales.Make
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
## but it there is space in the notation then . won't work
car_sales["Odometer (KM)"]
## car_sales.Odometer (KM)
# Out:
# 0    150043
# 1     87899
# 2     32549
# 3     11179
# 4    213095
# 5     99213
# 6     45698
# 7     54738
# 8     60000
# 9     31600
# Name: Odometer (KM), dtype: int64

# %%
## boolean indexing
car_sales[car_sales["Make"] == "Toyota"]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
## in panda 
## use & instead of and
## also close condtions within prenthesis

# %%
car_sales[(car_sales["Make"] == "Toyota") & (car_sales["Odometer (KM)"] > 70000)]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 5  Toyota  Green          99213      4  $4,500.00

# %% [markdown]
# ## crosstab

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
pd.crosstab(car_sales["Make"], car_sales["Doors"])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %% [markdown]
# ## groupby

# %%
car_sales.groupby(["Make"]).mean(numeric_only=True)
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
import matplotlib.pyplot as plt

# %%
car_sales["Odometer (KM)"].plot()
# Out:
# <Axes: >

# %%
car_sales["Odometer (KM)"].hist()
# Out:
# <Axes: >

# %%
car_sales["Doors"].plot()
# Out:
# <Axes: >

# %%
car_sales["Doors"].hist()
# Out:
# <Axes: >

# %%
car_sales["Price"] = car_sales["Price"].str.replace('[\$\,]','', regex=True).astype(float)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\$'
# <>:1: SyntaxWarning: invalid escape sequence '\$'
# /var/folders/j2/bny1m67s2_d0jg2q7zt0v2nh0000gn/T/ipykernel_8538/1817161573.py:1: SyntaxWarning: invalid escape sequence '\$'
#   car_sales["Price"] = car_sales["Price"].str.replace('[\$\,]','', regex=True).astype(float)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   4000.0
# 1   Honda    Red          87899      4   5000.0
# 2  Toyota   Blue          32549      3   7000.0
# 3     BMW  Black          11179      5  22000.0
# 4  Nissan  White         213095      4   3500.0
# 5  Toyota  Green          99213      4   4500.0
# 6   Honda   Blue          45698      4   7500.0
# 7   Honda   Blue          54738      4   7000.0
# 8  Toyota  White          60000      4   6250.0
# 9  Nissan  White          31600      4   9700.0

# %%
car_sales.Price.mean(numeric_only=True)
# Out:
# np.float64(7645.0)

# %%
car_sales.Price.plot()
# Out:
# <Axes: >

# %%
car_sales.Price.hist()
# Out:
# <Axes: >

# %% [markdown]
# ## Manipulating Data

# %%
## in ordeer to manipulate data, it should be reassigned to reflect the changes

# %%
car_sales["Make"] = car_sales["Make"].str.lower()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  toyota  White         150043      4   4000.0
# 1   honda    Red          87899      4   5000.0
# 2  toyota   Blue          32549      3   7000.0
# 3     bmw  Black          11179      5  22000.0
# 4  nissan  White         213095      4   3500.0
# 5  toyota  Green          99213      4   4500.0
# 6   honda   Blue          45698      4   7500.0
# 7   honda   Blue          54738      4   7000.0
# 8  toyota  White          60000      4   6250.0
# 9  nissan  White          31600      4   9700.0

# %%
car_sales_missing = pd.read_csv("car-sales-missing-data.csv")

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %% [markdown]
# ## for filling data, fillna method is used

# %%
car_sales_missing["Odometer"].mean(numeric_only=True)
# Out:
# np.float64(92302.66666666667)

# %%
car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean(numeric_only=True))
# Out:
# 0    150043.000000
# 1     87899.000000
# 2     92302.666667
# 3     11179.000000
# 4    213095.000000
# 5     92302.666667
# 6     92302.666667
# 7     92302.666667
# 8     60000.000000
# 9     31600.000000
# Name: Odometer, dtype: float64

# %%
car_sales_missing["Odometer"] = car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean(numeric_only=True))

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_sales_missing["Doors"].mean(numeric_only=True)
# Out:
# np.float64(4.0)

# %%
car_sales_missing["Doors"] = car_sales_missing["Doors"].fillna(car_sales_missing["Doors"].mean(numeric_only=True))

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    4.0      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %% [markdown]
# ## dropna

# %%
car_sales_missing = pd.read_csv("car-sales-missing-data.csv")

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing_dropped = car_sales_missing.dropna()

# %%
car_sales_missing_dropped
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing_dropped = pd.read_csv("car_sales_missing_dropped.csv")

# %%
car_sales_missing_dropped
# Out:
#    Unnamed: 0    Make Colour  Odometer  Doors    Price
# 0           0  Toyota  White  150043.0    4.0   $4,000
# 1           1   Honda    Red   87899.0    4.0   $5,000
# 2           3     BMW  Black   11179.0    5.0  $22,000
# 3           4  Nissan  White  213095.0    4.0   $3,500

# %%
car_sales_missing_dropped["Doors"].plot()
# Out:
# <Axes: >

# %%
# column from  Series

# %%
seats_column = pd.Series([5,5,5,5,5,5])
# not necessary to provide fo all the cars
# new column called seats to be added
# by deafault new column created will added to last of the column
car_sales["Seats"] = seats_column
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats
# 0  toyota  White         150043      4   4000.0    5.0
# 1   honda    Red          87899      4   5000.0    5.0
# 2  toyota   Blue          32549      3   7000.0    5.0
# 3     bmw  Black          11179      5  22000.0    5.0
# 4  nissan  White         213095      4   3500.0    5.0
# 5  toyota  Green          99213      4   4500.0    5.0
# 6   honda   Blue          45698      4   7500.0    NaN
# 7   honda   Blue          54738      4   7000.0    NaN
# 8  toyota  White          60000      4   6250.0    NaN
# 9  nissan  White          31600      4   9700.0    NaN

# %%
car_sales["Seats"].fillna(5)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats
# 0  toyota  White         150043      4   4000.0    5.0
# 1   honda    Red          87899      4   5000.0    5.0
# 2  toyota   Blue          32549      3   7000.0    5.0
# 3     bmw  Black          11179      5  22000.0    5.0
# 4  nissan  White         213095      4   3500.0    5.0
# 5  toyota  Green          99213      4   4500.0    5.0
# 6   honda   Blue          45698      4   7500.0    NaN
# 7   honda   Blue          54738      4   7000.0    NaN
# 8  toyota  White          60000      4   6250.0    NaN
# 9  nissan  White          31600      4   9700.0    NaN

# %%
# column from python list

# %%
fuel_economy = [7.5,9.0,8.5,9.5,10,12.0,11.5,11.0,11.0,10.0]
## must provide for all the index otherwise it will throw error called
## Length of values does not match length of index
car_sales["Fuel per 50Miles"] = fuel_economy
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 50Miles
# 0  toyota  White         150043      4   4000.0    5.0               7.5
# 1   honda    Red          87899      4   5000.0    5.0               9.0
# 2  toyota   Blue          32549      3   7000.0    5.0               8.5
# 3     bmw  Black          11179      5  22000.0    5.0               9.5
# 4  nissan  White         213095      4   3500.0    5.0              10.0
# 5  toyota  Green          99213      4   4500.0    5.0              12.0
# 6   honda   Blue          45698      4   7500.0    NaN              11.5
# 7   honda   Blue          54738      4   7000.0    NaN              11.0
# 8  toyota  White          60000      4   6250.0    NaN              11.0
# 9  nissan  White          31600      4   9700.0    NaN              10.0

# %%
## create colum from another column

# %%
car_sales["Total Fuel Used"] = car_sales["Odometer (KM)"] /100 * car_sales["Fuel per 50Miles"]
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 50Miles  \
# 0  toyota  White         150043      4   4000.0    5.0               7.5
# 1   honda    Red          87899      4   5000.0    5.0               9.0
# 2  toyota   Blue          32549      3   7000.0    5.0               8.5
# 3     bmw  Black          11179      5  22000.0    5.0               9.5
# 4  nissan  White         213095      4   3500.0    5.0              10.0
# 5  toyota  Green          99213      4   4500.0    5.0              12.0
# 6   honda   Blue          45698      4   7500.0    NaN              11.5
# 7   honda   Blue          54738      4   7000.0    NaN              11.0
# 8  toyota  White          60000      4   6250.0    NaN              11.0
# 9  nissan  White          31600      4   9700.0    NaN              10.0
#
#    Total Fuel Used
# 0        11253.225
# 1         7910.910
# 2         2766.665
# 3         1062.005
# 4        21309.500
# 5        11905.560
# 6         5255.270
# ...

# %%
## create a colum from single value

# %%
car_sales["No. of Wheels"] = 4
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 50Miles  \
# 0  toyota  White         150043      4   4000.0    5.0               7.5
# 1   honda    Red          87899      4   5000.0    5.0               9.0
# 2  toyota   Blue          32549      3   7000.0    5.0               8.5
# 3     bmw  Black          11179      5  22000.0    5.0               9.5
# 4  nissan  White         213095      4   3500.0    5.0              10.0
# 5  toyota  Green          99213      4   4500.0    5.0              12.0
# 6   honda   Blue          45698      4   7500.0    NaN              11.5
# 7   honda   Blue          54738      4   7000.0    NaN              11.0
# 8  toyota  White          60000      4   6250.0    NaN              11.0
# 9  nissan  White          31600      4   9700.0    NaN              10.0
#
#    Total Fuel Used  No. of Wheels
# 0        11253.225              4
# 1         7910.910              4
# 2         2766.665              4
# ...

# %%
## removing the column
## method drop()

# %%
car_sales.drop("Total Fuel Used", axis=1)
## below two were manipulated multiple times
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 50Miles  \
# 0  toyota  White         150043      4   4000.0    5.0               7.5
# 1   honda    Red          87899      4   5000.0    5.0               9.0
# 2  toyota   Blue          32549      3   7000.0    5.0               8.5
# 3     bmw  Black          11179      5  22000.0    5.0               9.5
# 4  nissan  White         213095      4   3500.0    5.0              10.0
# 5  toyota  Green          99213      4   4500.0    5.0              12.0
# 6   honda   Blue          45698      4   7500.0    NaN              11.5
# 7   honda   Blue          54738      4   7000.0    NaN              11.0
# 8  toyota  White          60000      4   6250.0    NaN              11.0
# 9  nissan  White          31600      4   9700.0    NaN              10.0
#
#    No. of Wheels
# 0              4
# 1              4
# 2              4
# 3              4
# 4              4
# 5              4
# 6              4
# ...

# %%
car_sales["No. of Wheels"].plot()
# Out:
# <Axes: >

# %%
car_sales["No. of Wheels"].hist()
# Out:
# <Axes: >

# %%
car_sales["Seats"].hist()
# Out:
# <Axes: >

# %%
## sample() method
## randmizing the row order
## frac means fraction , 0.5 means 50% of the data
## row number won't change

# %%
car_sales.sample(frac=.5)
# Out:
#      Make Colour  Odometer (KM)  Doors   Price  Seats  Fuel per 50Miles  \
# 5  toyota  Green          99213      4  4500.0    5.0              12.0
# 9  nissan  White          31600      4  9700.0    NaN              10.0
# 0  toyota  White         150043      4  4000.0    5.0               7.5
# 4  nissan  White         213095      4  3500.0    5.0              10.0
# 2  toyota   Blue          32549      3  7000.0    5.0               8.5
#
#    Total Fuel Used  No. of Wheels
# 5        11905.560              4
# 9         3160.000              4
# 0        11253.225              4
# 4        21309.500              4
# 2         2766.665              4

# %%
car_sales_suffled = car_sales.sample(frac=.5)

# %%
car_sales_suffled
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 50Miles  \
# 7   honda   Blue          54738      4   7000.0    NaN              11.0
# 3     bmw  Black          11179      5  22000.0    5.0               9.5
# 9  nissan  White          31600      4   9700.0    NaN              10.0
# 2  toyota   Blue          32549      3   7000.0    5.0               8.5
# 6   honda   Blue          45698      4   7500.0    NaN              11.5
#
#    Total Fuel Used  No. of Wheels
# 7         6021.180              4
# 3         1062.005              4
# 9         3160.000              4
# 2         2766.665              4
# 6         5255.270              4

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 50Miles  \
# 0  toyota  White         150043      4   4000.0    5.0               7.5
# 1   honda    Red          87899      4   5000.0    5.0               9.0
# 2  toyota   Blue          32549      3   7000.0    5.0               8.5
# 3     bmw  Black          11179      5  22000.0    5.0               9.5
# 4  nissan  White         213095      4   3500.0    5.0              10.0
# 5  toyota  Green          99213      4   4500.0    5.0              12.0
# 6   honda   Blue          45698      4   7500.0    NaN              11.5
# 7   honda   Blue          54738      4   7000.0    NaN              11.0
# 8  toyota  White          60000      4   6250.0    NaN              11.0
# 9  nissan  White          31600      4   9700.0    NaN              10.0
#
#    Total Fuel Used  No. of Wheels
# 0        11253.225              4
# 1         7910.910              4
# 2         2766.665              4
# ...

# %%
## only on 30% of data that is already suffled
car_sales_suffled.sample(frac=.3)
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 50Miles  \
# 9  nissan  White          31600      4   9700.0    NaN              10.0
# 3     bmw  Black          11179      5  22000.0    5.0               9.5
#
#    Total Fuel Used  No. of Wheels
# 9         3160.000              4
# 3         1062.005              4

# %%
## to reset the index of suffled data
## use reset_index() method

# %%
car_sales_suffled.reset_index(drop=True, inplace=False)
# this will not update the car_sales_suffled
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 50Miles  \
# 0   honda   Blue          54738      4   7000.0    NaN              11.0
# 1     bmw  Black          11179      5  22000.0    5.0               9.5
# 2  nissan  White          31600      4   9700.0    NaN              10.0
# 3  toyota   Blue          32549      3   7000.0    5.0               8.5
# 4   honda   Blue          45698      4   7500.0    NaN              11.5
#
#    Total Fuel Used  No. of Wheels
# 0         6021.180              4
# 1         1062.005              4
# 2         3160.000              4
# 3         2766.665              4
# 4         5255.270              4

# %%
car_sales_suffled = car_sales_suffled.reset_index(drop=False, inplace=False)
car_sales_suffled
# Out:
#    index    Make Colour  Odometer (KM)  Doors    Price  Seats  \
# 0      7   honda   Blue          54738      4   7000.0    NaN
# 1      3     bmw  Black          11179      5  22000.0    5.0
# 2      9  nissan  White          31600      4   9700.0    NaN
# 3      2  toyota   Blue          32549      3   7000.0    5.0
# 4      6   honda   Blue          45698      4   7500.0    NaN
#
#    Fuel per 50Miles  Total Fuel Used  No. of Wheels
# 0              11.0         6021.180              4
# 1               9.5         1062.005              4
# 2              10.0         3160.000              4
# 3               8.5         2766.665              4
# 4              11.5         5255.270              4

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 50Miles  \
# 0  toyota  White         150043      4   4000.0    5.0               7.5
# 1   honda    Red          87899      4   5000.0    5.0               9.0
# 2  toyota   Blue          32549      3   7000.0    5.0               8.5
# 3     bmw  Black          11179      5  22000.0    5.0               9.5
# 4  nissan  White         213095      4   3500.0    5.0              10.0
# 5  toyota  Green          99213      4   4500.0    5.0              12.0
# 6   honda   Blue          45698      4   7500.0    NaN              11.5
# 7   honda   Blue          54738      4   7000.0    NaN              11.0
# 8  toyota  White          60000      4   6250.0    NaN              11.0
# 9  nissan  White          31600      4   9700.0    NaN              10.0
#
#    Total Fuel Used  No. of Wheels
# 0        11253.225              4
# 1         7910.910              4
# 2         2766.665              4
# ...

# %%
car_sales["Odometer (KM)"] = car_sales["Odometer (KM)"].rename(columns={"Odometer (KM)": "Odometer (Miles)"})
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 50Miles  \
# 0  toyota  White         150043      4   4000.0    5.0               7.5
# 1   honda    Red          87899      4   5000.0    5.0               9.0
# 2  toyota   Blue          32549      3   7000.0    5.0               8.5
# 3     bmw  Black          11179      5  22000.0    5.0               9.5
# 4  nissan  White         213095      4   3500.0    5.0              10.0
# 5  toyota  Green          99213      4   4500.0    5.0              12.0
# 6   honda   Blue          45698      4   7500.0    NaN              11.5
# 7   honda   Blue          54738      4   7000.0    NaN              11.0
# 8  toyota  White          60000      4   6250.0    NaN              11.0
# 9  nissan  White          31600      4   9700.0    NaN              10.0
#
#    Total Fuel Used  No. of Wheels
# 0        11253.225              4
# 1         7910.910              4
# 2         2766.665              4
# ...
