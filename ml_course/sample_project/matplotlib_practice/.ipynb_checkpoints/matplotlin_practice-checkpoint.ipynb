# %%
## import
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.plot()
plt.show()

# %%
## ploting using python list
plt.plot([2,5,8,3])
plt.show()

# %%
x = np.array([1,3,4,8,9])
x
# Out:
# array([1, 3, 4, 8, 9])

# %%
y = np.array([10,25,32,38,50])
y
# Out:
# array([10, 25, 32, 38, 50])

# %%
## ploting and created x and y list
plt.plot(x,y)
plt.show()

# %%
## using subplot 
fig, ax = plt.subplots(
    figsize=(10,6)
)
ax.plot(x,y)
plt.show()

# %% [markdown]
# ## matplot workflow Example

# %%
x1 = np.random.randint(1, 9, size=(1, 7))
x1
# Out:
# array([[6, 4, 7, 1, 2, 1, 5]])

# %%
x2 =
# Out:
# numpy.ndarray
